# %%
import pystan
import stan_utility
import matplotlib.pyplot as plot
import numpy as np
import pandas as pd
import banocc
import sys
import os

# %%
synthetic = pd.read_csv('SyntheticMicrobiome.tsv', sep = '\t')
synthetic.set_index('#SampleID', inplace = True)

# %%
synthetic = synthetic.iloc[4:,:].astype(float)
synthetic.iloc[0:426,:]
# Out:
#                         Sample1   Sample2   Sample3   Sample4   Sample5  \
# #SampleID
# Feature_Lognormal_1    0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_2    0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_3    0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_4    0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_5    0.000000  0.000000  0.015081  0.000000  0.000468
# ...                         ...       ...       ...       ...       ...
# Feature_Lognormal_422  0.000000  0.009404  0.000000  0.000000  0.000000
# Feature_Lognormal_423  0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_424  0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_425  0.000000  0.000000  0.000000  0.000000  0.000000
# Feature_Lognormal_426  0.014556  0.000000  0.000000  0.005468  0.008065
#
#                         Sample6   Sample7   Sample8   Sample9  Sample10  \
# #SampleID
# ...

# %%
synthetic.iloc[0:426,:].transpose().to_csv('composition.csv', sep = '\t', index = False, header = False)

# %%
test = banocc.run_banocc(synthetic.iloc[0:426,:].transpose())
# Out:
# Converted C to numpy
# Checking C
# Started model fitting
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/alexis/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/alexis/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "stanfit4anon_model_c9b5e359d78404f0d4fb04450f335f15_4796389180731848910.pyx", line 373, in stanfit4anon_model_c9b5e359d78404f0d4fb04450f335f15_4796389180731848910._call_sampler_star
#   File "stanfit4anon_model_c9b5e359d78404f0d4fb04450f335f15_4796389180731848910.pyx", line 406, in stanfit4anon_model_c9b5e359d78404f0d4fb04450f335f15_4796389180731848910._call_sampler
# RuntimeError: Initialization failed.
# """
#
# ...
